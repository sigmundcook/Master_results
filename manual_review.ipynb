# %% [markdown]
# H21
#
# Oppgave 2a
#
# AttributeError("'str' object has no attribute 'max'")
#
# def alfa(streng,tall):
#     if int != 0:
#         return streng.max()
#     else:
#         return streng.min()
#
# Logical Errors:
# The check if int != 0: is incorrect. Here, you are comparing the class int with the value 0. This condition will always evaluate to True because you are comparing two different types. You might want to check if tall is not equal to 0 instead.
#
# Syntax Errors:
# There are no syntax errors in the code. The code will run, but it might not produce the desired output due to the logical errors mentioned above.
#
# Runtime Errors:
# The AttributeError: 'str' object has no attribute 'max' occurs because the student is trying to call the max() method on a string object (streng). Strings do not have max() or min() methods. When you wish to find the maximum or minimum character in a string, you can use the built-in max() and min() functions.
#
#
# ValueError("could not convert string to float: 'abc'")
#
# def alfa(streng, tall):
#     if float(tall) == 0:
#         return min(streng)
#     else:
#         return max(streng)
#
# Logical Errors:
# The function alfa is using the tall parameter. However, the ValueError suggests that the student is trying to convert a non-numeric string, in this case 'abc', to a float.
#
# Runtime Errors:
# The ValueError: "could not convert string to float: 'abc'" occurs because you are trying to convert the string 'abc' to a float using float(tall). The string 'abc' cannot be converted to a float as it does not represent a valid number.
#
#
# AssertionError("'u' != 'a'\n- u\n+ a\n")
#
# def alfa(streng,tall):
#     if tall==0:
#         return max(streng)
#     else:
#         return min(streng)
#
# Logical Errors:
# The code in this submission does not contain any runtime or syntax errors, but the if statement is incorrect, which leads to the code returning the incorrect value for the assertion tests.

# %% [markdown]
# Oppgave 2b
#
# AssertionError('1 != 3')
#
# def ant_land(geografi):
#     for i in geografi:
#         geografi=len(str(geografi))
#     return geografi
#
# Logical Errors:
#
# Incorrect variable assignment:
# Inside the for loop, the variable 'geografi' is reassigned to the length of the string representation of 'geografi'. This means that for each iteration of the loop, 'geografi' will be overwritten with the length of the input instead of iterating over the elements.
#
# TypeError("unhashable type: 'dict_keys'")
#
# def ant_land(geografi):
#     dic = {}
#     for i in range(len(geografi)):
#         geografi = dic[geografi.keys()]
#     return geografi
#
# Logical Errors:
#
# Incorrect usage of dictionary keys:
# Inside the for loop, the code attempts to access dictionary keys using geografi.keys(). However, geografi seems to be a dictionary itself, and accessing .keys() on it returns a dictionary_keys object. This object is not hashable, which is why the TypeError occurs when trying to use it as a dictionary key.
#
# Runtime Errors:
#
# The TypeError occurs when the code attempts to use an unhashable object as a dictionary key, violating the hashability requiremen
#
# TypeError("'int' object is not iterable")
#
# def ant_land(geografi):
#     antall = len(geografi)
#     for land in antall:
#         if land[0] == land[1]:
#             return land
#
# Logical Errors:
#
# Incorrect iteration variable:
# In the for loop, the code attempts to iterate over antall, which is assigned the length of geografi. However, antall is an integer obtained from len(geografi), and integers are not iterable. To iterate over the elements of an array, the iteration variable should be assigned the array itself, not its length.

# %% [markdown]
# Oppgave 2c
#
# TypeError('list indices must be integers or slices, not str')
#
# def sjekk(tall):
#     if tall.is_integer():
#         if tall % 2 == 0:
#             return "par"
#         else:
#             return "odde"
#     else:
#         return "des"
#
# Runtime Errors:
#
# The TypeError occurs when the code tries to use a string (str) as an index to access elements of a list. List indices must be integers or slices, not strings. If the student wants to check if tall is an integer or not the method is_integer can be replaced with isinstance(tall,int)
#
#
# IndexError('list index out of range')
#
# def sjekk(tall):
#     string = str(tall)
#     list = string.split('.')
#     if list[1] == '0':
#         if tall % 2 == 0:
#             return 'par'
#         elif tall % 2 != 0:
#             return 'odde'
#     else:
#         return 'des'
#
# Logical Errors:
#
# Incorrect handling of non-decimal numbers:
# The code assumes that the input tall is a decimal number and splits it by the decimal point using string.split('.'). However, if tall is an integer or a non-decimal number, splitting it by the decimal point will result in a list with only one element. Accessing list[1] in such cases will cause an IndexError because the index is out of range.
#
#
# AssertionError("None != 'odde'")
#
# def sjekk(tall):
#
#     if len(str(tall).split(".")) > 1:
#         if int(str(tall).split(".")[1]) > 0:
#             return "dec"
#
#     elif tall % 2 == 0:
#         return "par"
#
#     else:
#         return "odde"
#
# Logical Errors:
#
# Missing return statement for 'dec':
# If the length of the split result is greater than 1 and the second part is greater than 0, the code returns "dec". However, if the decimal number is for example 3.0 this could potentially lead to the function returning if the condition is not met.

# %% [markdown]
# Oppgave 2g
#
# AssertionError('None != [1, 4, 3, 2]')
#
# def fjern_dup(liste):
#     for i in range(1,len(liste)):
#         if liste[i] == liste[i-1]:
#             liste[i] = "a"
#
#     for j in liste:
#         if j == "a":
#             liste.remove(j)
#
# Logical Errors:
#
# Missing return statement for list:
# The code is missing a return statement for the list, which resulsts in the assertion failing as the code returns none instead of the list.
#
#
# AssertionError("'[1, 4, 3, 2]' != [1, 4, 3, 2]")
#
# def fjern_dup(liste):
#     duplikat = []
#     for i in liste:
#         if i not in duplikat:
#             duplikat.append(i)
#     return str(duplikat)
#
# Logical Errors:
#
# Returning a string representation of the list:
# The code uses the str() function to convert the duplikat list to a string before returning it. As a result, the function returns a string representation of the list instead of the actual list object.
#
# IndexError('list index out of range')
#
# def fjern_dup(liste):
#     for i in range(1, len(liste)):
#         if liste[i] == liste[i-1]:
#             del liste[i]
#     return liste
#
# Logical Errors:
#
# Modifying a list while iterating over it:
# The code attempts to remove elements from the liste while iterating over it using the for loop. Modifying a list by deleting elements while iterating can lead to unexpected behavior and errors. In this case, when an element is deleted at index i, the length of the list decreases, and the loop continues to iterate up to the original length, causing the IndexError.

# %% [markdown]
# Oppgave 2h
#
# ValueError('substring not found')
#
# def list_str(s):
#     ny_liste = []
#     for i in range(len(s)):
#         if s.index('c') == s[i-3]:
#             if s.index('c') == s[i+4]:
#                 ny_liste.append(i)
#     return ny_liste
#
# Logical Errors:
#
# Incorrect usage of index() method:
# The code attempts to use the index() method to find the index of the substring 'c' in the string s. However, the usage of index() is incorrect in this context. The index() method searches for the first occurrence of the specified substring and raises a ValueError if the substring is not found. In this case, you are comparing the result of s.index('c') with specific indices (s[i-3] and s[i+4]), which may lead to incorrect results and cause the ValueError.
#
# TypeError('can only concatenate str (not "int") to str')
#
# def list_str(s):
#     liste = []
#     for i in s:
#         if 'd' and 'c' not in s:
#             return []
#         elif s[i+3] == 'd' and s[i-3] == 'c':
#             liste.append(i)
#     return liste
#
# Logical Errors:
#
# Incorrect usage of the loop variable:
# In the for loop, the code iterates over the characters in the string s, assigning each character to the loop variable i. However, later in the code, you attempt to use i as an index in the expression s[i+3] and s[i-3]. Since i represents a character, not an index, this leads to incorrect indexing and the resulting TypeError.
#
#
# AssertionError("Lists differ: ['f'] != []\n\nFirst list contains 1 additional elements.\nFirst extra element 0:\n'f'\n\n- ['f']\n+ []")
#
# def list_str(s):
#       liste=[]
#       for i in range(3, len(s)):
#             if s[i] == 'c' and s[i - 6] == 'd':
#                   liste.append(s[i-3])
#
#       return liste
#
# Logical Errors:
#
# Incorrect condition for appending elements to the list:
# The code appends s[i-3] to liste when s[i] == 'c' and s[i-6] == 'd'. However, this condition may not be sufficient to achieve the desired result, as there could be other 'c' and 'd' characters in the string that don't match this specific pattern. This might lead to incorrect elements being appended to the list.

# %% [markdown]
# Oppgave 2i
#
# AssertionError('1 != 2')
#
# def sjekk_to(streng):
#     first = int(streng[0]) + int((streng[1]))
#     second = int(streng[2]) + int((streng[3]))
#     third = int(streng[4]) + int((streng[5]))
#     f = False
#     s = False
#     t = False
#     if first <= 29:
#         f = True
#     if second <=16:
#         s = True
#     if third <= 58:
#         t = True
#     if f == True and s == True and t == True:
#         return 1
#     elif f == False and s == True and t == True:
#         return 2
#     elif f == True and s == False and t == True:
#         return 3
#     elif f == True and s == True and t == False:
#         return 5
#     elif f == False and s == False and t == True:
#         return 6
#     elif f == False and s == True and t == False:
#         return 10
#     elif f == False and s == False and t == False:
#         return 30
#
# Logical Errors:
#
# Incorrect conditions for the return values:
# The code calculates three sums (first, second, and third) based on specific indices of the input streng. Then, it checks these sums against certain thresholds to set the Boolean variables f, s, and t accordingly. The code uses these Boolean variables to determine the return value. However, the conditions for the return values seem to be incorrect, as they don't match the expected mapping of the Boolean variables.
#
# TypeError("'>' not supported between instances of 'str' and 'int'")
#
# def sjekk_to(streng):
#     if streng[0] > 2:
#          return 2
#     elif streng[0] == 2 and streng[1] > 7:
#         return 2
#
#     elif streng[2] > 1:
#         return 3
#     elif streng[2] == 1 and streng[3] > 4:
#         return 3
#
#     elif streng[4] > 5:
#         return 5
#     elif streng[4] == 5 and streng[5] > 4:
#         return 5
#
# Comparing string values with integer values:
# The code attempts to compare the characters of streng with integer values using the greater than (>) and equality (==) operators. However, the elements of streng are string values since they are accessed using indexing. Comparing a string with an integer using these operators leads to a TypeError. Code is also incomplete and does not account for all cases of the task
#
# IndexError('list index out of range')
#
# def sjekk_to(streng):
#     streng = streng.replace('', ',')
#     streng = streng.split()
#     if (streng[0] + streng[1]) <= 25 and (streng[2] + streng[3]) <= 18 and streng[4] + streng[5] <= 52:
#         return 1
#
# Logical Errors:
#
# Incorrect splitting of the string:
# The code attempts to split the streng string by replacing empty strings with commas and then splitting using whitespace as a delimiter. However, this splitting technique does not result in the desired list of elements. Additionally, it can lead to an IndexError if the resulting list does not have enough elements to access with the specified indices. Code is also incomplete and does not account for the cases of the task, it will instead only return 1 if a specific condition is met.

# %% [markdown]
# Oppgave 3_1
#
# AssertionError('0 != 99')
#
# def finn_pris(matvarer,let_etter):
#     for mat in matvarer:
#         if mat[0] == let_etter:
#             return mat[1]
#         else:
#             return 0
#
# Logical Errors:
#
# Incorrect use of return statements:
# The code uses a return statement within the for loop, which causes the loop to terminate and return a value after the first iteration. This means that the loop may not check all the elements of matvarer if the desired letter is not found in the first iteration.
#
# UnboundLocalError("local variable 'matvarer' referenced before assignment")
#
# def finn_pris(matbvarer, let_etter):
#     for matvarer in matvarer:
#
#         if let_etter in matvarer[0]:
#             return matvarer[1]
#
#     else:
#         return "0"
#
# Logical Errors:
#
# Variable name conflict:
# The code has a variable name conflict where the loop variable matvarer has the same name as the matvarer parameter of the function. This leads to confusion and unintended behavior.
#
# Syntax Errors:
#
# The line return "0" should be modified to return 0 to return an integer value instead of a string.
#
# TypeError("finn_pris() missing 1 required positional argument: 'let_etter'")
#
# def finn_pris(matvarer, let_etter):
#     for x in finn_pris(matvarer):
#         if (finn_pris(let_etter) == x):
#             return let_etter
#         else:
#             return 0
#
# Recursive function call:
# The code attempts to call the finn_pris() function recursively within the loop. The expected code should loop through the given list matvarer and compare the current values to let_etter.

# %% [markdown]
# Oppgave 3_2
#
# AssertionError("13 != {'laks': 6, 'kjøttdeig': 13, 'ris': 15, '[43 chars]': 5}")
#
# def oppdater_matvare(beholdning, matvare, antall):
#     beholdning[matvare] += antall
#     return beholdning[matvare]
#
# Logical Errors:
#
# Incorrect expected value:
# This code returns beholdning[matvare] instead of beholdning, which gives an incorrect assertion
#
# KeyError(-1)
#
# def oppdater_matvare(beholdning, matvare, antall):
#     for i in beholdning:
#         if antall != beholdning[antall]:
#             beholdning.append(antall)
#
# Incorrect usage of dictionary:
# The code attempts to iterate over the keys of the beholdning dictionary using the loop variable i. However, within the loop, it tries to access the value using beholdning[antall]. This usage is incorrect because antall is not a key but a variable representing the number of items. This leads to a KeyError when -1 is used as a key.
#
# TypeError('oppdater_matvare() takes 2 positional arguments but 3 were given')
#
# def oppdater_matvare(beholdning, matvare):
#     for mat in beholdning:
#         if mat[0] == matvare[0]:
#             if mat[1] >= matvare[1]:
#                 mat[1] += matvare[1]
#     return beholdning
#
# Logical Errors:
#
# Incorrect number of arguments:
# The function definition of oppdater_matvare specifies two parameters: beholdning and matvare. However, in the function call, it seems that three arguments are provided, which leads to the TypeError. The code should include the parameter antall, in order to update the values using the provided parameters.

# %% [markdown]
# Oppgave 3_3
#
# TypeError('tuple indices must be integers or slices, not list')
#
# def oppdater_beholdning(beholdning, endring):
#     for vare in endring:
#         oppdat = int(endring[vare][1])
#         beholding[vare]+=oppdat
#     return beholdning
#
# Logical Errors:
#
# Incorrect variable name:
# The error message suggests that the variable beholding is used instead of beholdning in the loop body. This causes a NameError because beholding is not defined anywhere.
#
# The TypeError occurs when the code tries to use a list as an index for accessing elements in another list, which is not supported.
#
# Incorrect indexing of the endring list:
# The code tries to access elements in the endring list using vare as the index. However, vare is a list itself, which is not a valid type for indexing a list.
#
# AssertionError("{'ost': 2, 'bønner': 4, 'laks': 2, 'kjøttdeig': -3} != {'laks': 8, 'kjøttdeig': 11, 'ris': 15, 'os[43 chars]': 5}\n- {'bønner': 4, 'kjøttdeig': -3, 'laks': 2, 'ost': 2}\n+ {'banan': 5,\n+  'bønner': 10,\n+  'kjøttdeig': 11,\n+  'laks': 8,\n+  'ost': 11,\n+  'ris': 15,\n+  'soyasaus': 0}")
#
# def oppdater_beholdning(beholdning, endringer):
#     beholdning = dict(endringer)
#     return beholdning
#
# Logical Errors:
#
# Overwriting the beholdning parameter:
# The code assigns a new dictionary dict(endringer) to the beholdning variable, effectively overwriting the original beholdning dictionary. This results in a different dictionary being returned than the expected output. The code should not overwrite the original dictionary, but rather edit the changes from the endringer parameter into the beholdning dictionary.
#
# AttributeError("'tuple' object has no attribute 'insert'")
#
# def oppdater_beholdning(beholdning, endringer):
#     ny_beholdning = []
#     for matvare in endringer:
#         endringer = endringer.insert([matvare, int(antall)])
#     return ny_beholdning
#
# Logical Errors:
#
# Incorrect usage of insert method:
# The code attempts to use the insert method on the endringer tuple, which is not allowed because tuples do not have an insert method.

# %% [markdown]
# Oppgave 3_4
#
# AssertionError("None != [('bønner', 7), ('soyasaus', 33), ('ris', 15)]")
#
# def vis_priser(beholdning, matvarer, tekst):
#     liste_med_tupler = []
#     for i in range(len(beholdning)):
#         liste_beholdning = list(beholdning.keys())
#         if liste_beholdning[i] in tekst:
#             tuppel = (liste_beholdning[i], beholdning[liste_beholdning[i]])
#
# Logical Errors:
#
# Incomplete tuple creation:
# The code creates a tuple tuppel but doesn't append it to the liste_med_tupler list. As a result, the liste_med_tupler list remains empty. Aditionally it does not contain a return statement, which results in the function returning None
#
# TypeError('must be str or None, not type')
#
# def vis_priser(beholdning, matvarer, tekst):
#     retur = []
#     liste = tekst.split(str)
#     for i in range(len(matvarer)):
#         for j in range(len(liste)):
#             if liste[j] == liste[i][0]:
#                 retur.append(liste[j], matvarer[i][1])
#
#     return retur
#
# Logical Errors:
#
# Incorrect usage of str function:
# In the line liste = tekst.split(str), the code attempts to split the tekst string using the str function as the delimiter. However, the str function should be used to convert objects to strings and is not intended for use as a delimiter in the split method.
#
# KeyError(0)
#
# def vis_priser(beholdning, matvarer, tekst):
#     ny_tekst = tekst.split()
#     liste = []
#     for i in range(len(beholdning)):
#         if ny_tekst[i] in beholdning.keys():
#             liste = liste.append(beholdning[i])
#     return tupple(liste)
#
# Logical Errors:
#
# Incorrect indexing of the beholdning dictionary:
# The code tries to access elements in the beholdning dictionary using an index i. However, dictionaries are not accessed using indices but rather by specifying the key.

# %% [markdown]
# Opgpave 3_5
#
# AssertionError("None != ('laks', 'kjøttdeig', 'ris', 'ost', 'bønner', 'banan')")
#
# def salg(m, b, h):
#     selges = ''
#     solgt = ()
#     tempb = b
#     for i in range(len(m)):
#         selges = selges + m[i][0] +' for '+str(m[i][1])+'kr, '
#
# Logical Errors:
#
# Incomplete tuple creation:
# The code concatenates strings to the selges variable but does not create a tuple or assign it to the solgt variable. As a result, the solgt variable remains None. Also the code does not return any variables from the function.
#
# TypeError("'>' not supported between instances of 'str' and 'int'")
#
# def salg(matvarer, beholdning, handleliste):
#     sluttsumm = 0
#     solgte_matvarer = ()
#     for matvarer in beholdning:
#         if matvarer > 2:
#             solgte_matvarer.append(matvarer)
#             sluttsom += 1
#
#     return sluttsumm and matvarer
#
# Logical Errors:
#
# Incorrect comparison of variables:
# The code uses the same variable name matvarer for the loop variable and the loop iteration. This overwrites the original matvarer input parameter, causing unexpected behavior.
#
# Incorrect usage of > operator:
# The code tries to compare matvarer (which is a string) with the integer 2 using the > operator. However, this comparison is not valid since the > operator is not supported between a string and an integer.
#
# UnboundLocalError("local variable 'oppdatert_beholdning' referenced before assignment")
#
# def salg(matvarer, beholdning, handleliste):
#     solgte_matvarer = []
#
#     oppdatert_beholdning -= solgte_matvare
#     return solgte_matvarer
#
# Incorrect assignment and usage of oppdatert_beholdning:
# The code tries to subtract solgte_matvare from oppdatert_beholdning, but the oppdatert_beholdning variable is not assigned any value before this operation. This leads to an UnboundLocalError.

# %% [markdown]
# H22morgen
#
# Oppgave 1
#
# AssertionError('3 != 11')
#
# def sum_except(numlist, n):
#     summen = 0
#     for i in range(len(numlist)):
#         if i != n:
#             summen += i
#
#     return summen
#
# Incorrect usage of loop variable:
# In the line summen += i, the code mistakenly adds the loop variable i to the summen variable, rather than adding the corresponding value from the numlist.
#
# Incorrect range for iteration:
# The code uses range(len(numlist)) to iterate over the indices of numlist. However, it should iterate over the elements of numlist instead.
#
# AttributeError("'list' object has no attribute 'strip'")
#
# def sum_except(numlist,n):
#     ny_numliste = numlist.strip(n).slip()
#     a = numpy.array(ny_numlist)
#     summen_av_liste = numpy.sum(a)
#     return summem_av_liste
#
# Incorrect usage of strip and slip methods:
# The code tries to use the strip and slip methods on a list object numlist. However, neither of these methods exists for lists. The strip method is used to remove leading and trailing characters from strings, and slip is not a valid method.
#
# UnboundLocalError("local variable 'sum' referenced before assignment")
#
# import numpy as np
# def sum_except(numlist, n):
#     summer=0
#     for i in range (len(numlist)):
#         if numlist[i]!=n:
#             sum+=numlist[i]
#     return summer
#
# Incorrect variable name:
# The code uses the variable name summer to accumulate the sum, but then tries to assign the sum to a variable named sum, which conflicts with the built-in sum function in Python.
#
# Oppgave 2
#
# AssertionError('False is not true : False')
#
# def ok_size(length, width, intl):
#     if intl == False:
#         if (90 <= length <= 120) and (45 <= width <= 90): #Bruker and for at begge betingelsene m√• stemme for at funksjonen skal returnere True.
#             return True
#         else:
#             return False
#     elif intl == True:
#         if (100 <= length <= 110) and (64 <= width <= 75):
#             return True
#         else:
#             return False
#
# Incorrect logic for assertion:
# The error message suggests that the expected value is True, but the condition in the assert statement is checking if the return value is False. This mismatch causes the AssertionError. The code uses incorrect logic which causes the assertion to fail.
#
# NameError("name 'lenght' is not defined")
#
# def ok_size(length, width, intl):
#     if intl == True:
#         if (100 <= lenght <= 110) & (64 <= width <= 75):
#             return True
#         else:
#             return False
#     else:
#         if (90 <= lenght <= 120) & (45 <= width <= 90):
#             return True
#         else:
#             return False
#
# Typo in variable name:
# The code mistakenly uses the variable name lenght instead of length in the conditions. This causes the NameError because lenght is not defined.
#
# TypeError("'<' not supported between instances of 'float' and 'str'")
#
# def ok_size(lenght, width, intl):
#
#     while intl == True:
#         if float(100) < 'length' < float(110) and float(64) < 'width' < float(75):
#             return True
#         else:
#             return False
#
#     if float(90) < 'length' < float(120) and float(45) < 'width' < float(90):
#         return True
#     else:
#         return False
#     return
#
# Incorrect usage of quotes around variables:
# The code mistakenly wraps the variables length and width with quotes, turning them into string literals. This causes a TypeError when trying to compare them using the < operator with float values.
#
#
# Oppgave 3
#
# IndexError('index 1 is out of bounds for axis 0 with size 1')
#
# def count_local_min(A):
#     count = 0
#
#     for i in range(len(A)):
#         for j in range(len(A[i])):
#             tall_rundt = []
#             tall = A[i][j]
#             minima = True
#
#             tall_rundt.append(A[i][j::-1])
#             tall_rundt.append(A[i][j:])
#             tall_rundt.append(A[i::-1][j])
#             tall_rundt.append(A[i:][j])
#
#             for el in tall_rundt:
#                 if len(el)>1:
#                     if el[1] < tall:
#                         minima = False
#                         break
#             if minima:
#                 count += 1
#
#     return count
#
# ValueError('The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()')
#
# def count_local_min(A):
#     antall = 0
#     for i in range(len(A)):
#         for j in range(len(A[i])):
#             if (A[i] < A[i+1] and A[i] < A[i-1] and A[j]<A[j+1] and A[j]<A[j-1]) and A[i]< A[i-1][j] and A[i]<A[i+1][j]:
#                 antall +=1
#
#     return antall
#
# IndexError('index 4 is out of bounds for axis 0 with size 4')
#
# def count_local_min(A):
#     local_min_num = 0
#     local_list = []
#
#     for i in range(len(A)):
#         for j in range(len(A[i])):
#             if i == 0 and j == 0:
#                 local_list.append(A[i][j])
#                 local_list.append(A[i+1][j])
#                 local_list.append(A[i][j+1])
#                 local_list.append(A[i+1][j+1])
#
#                 if local_list[0] == min(local_list):
#                     local_min_num += 1
#
#                 local_list.clear()
#             elif i == 0:
#                 local_list.append(A[i][j])
#                 local_list.append(A[i][j-1])
#                 local_list.append(A[i+1][j-1])
#                 local_list.append(A[i+1][j])
#                 local_list.append(A[i][j+1])
#                 local_list.append(A[i+1][j+1])
#
#                 if local_list[0] == min(local_list):
#                     local_min_num += 1
#
#                 local_list.clear()
#
#             elif j == 0:
#                 local_list.append(A[i][j])
#                 local_list.append(A[i-1][j])
#                 local_list.append(A[i+1][j])
#                 local_list.append(A[i-1][j+1])
#                 local_list.append(A[i][j+1])
#                 local_list.append(A[i+1][j+1])
#
#                 if local_list[0] == min(local_list):
#                     local_min_num += 1
#
#                 local_list.clear()
#             else:
#                 local_list.append(A[i][j])
#                 local_list.append(A[i-1][j-1])
#                 local_list.append(A[i][j-1])
#                 local_list.append(A[i+1][j-1])
#                 local_list.append(A[i-1][j])
#                 local_list.append(A[i+1][j])
#                 local_list.append(A[i-1][j+1])
#                 local_list.append(A[i][j+1])
#                 local_list.append(A[i+1][j+1])
#
#                 if local_list[0] == min(local_list):
#                     local_min_num += 1
#
#                 local_list.clear()
#
#     return local_min_num
#
# Incorrect index access:
# The code tries to access elements A[i+1][j] and A[i+1][j+1] when i reaches the maximum value in the loop. This causes an IndexError because these indices are out of bounds for the array.

# %% [markdown]
# Incorrect usage of loop variable:
# In the line summen += i, the code mistakenly adds the loop variable i to the summen variable, rather than adding the corresponding value from the numlist.
#
# Incorrect range for iteration:
# The code uses range(len(numlist)) to iterate over the indices of numlist. However, it should iterate over the elements of numlist instead.
#
# Incorrect usage of strip and slip methods:
# The code tries to use the strip and slip methods on a list object numlist. However, neither of these methods exists for lists. The strip method is used to remove leading and trailing characters from strings, and slip is not a valid method.
#
# Incorrect variable name:
# The code uses the variable name summer to accumulate the sum, but then tries to assign the sum to a variable named sum, which conflicts with the built-in sum function in Python.
#
# Incorrect logic for assertion:
# The error message suggests that the expected value is True, but the condition in the assert statement is checking if the return value is False. This mismatch causes the AssertionError. The code uses incorrect logic which causes the assertion to fail.
#
# Typo in variable name:
# The code mistakenly uses the variable name lenght instead of length in the conditions. This causes the NameError because lenght is not defined.
#
# Incorrect usage of quotes around variables:
# The code mistakenly wraps the variables length and width with quotes, turning them into string literals. This causes a TypeError when trying to compare them using the < operator with float values.
#
# Incorrect index access:
# The code tries to access elements around the current element A[i][j] in different directions using slicing. However, the slicing indices are incorrect, leading to the IndexError.
#
# Incorrect array comparisons:
# The code compares arrays A[i], A[i+1], A[i-1], A[j], A[j+1], and A[j-1] using < operator. However, the < operator should be used for element-wise comparisons, not array-wise comparisons.
#
# Incorrect index access:
# The code tries to access elements A[i+1][j] and A[i+1][j+1] when i reaches the maximum value in the loop. This causes an IndexError because these indices are out of bounds for the array.

# %% [markdown]
# H22Kveld
#
# Oppgave 1
#
# TypeError("'list' object is not callable")
#
# def sum_larger(numlist,n):
#     ny_liste = []
#     for i in numlist(len(numlist)):
#         if numlist[i] > n:
#             ny_liste.append(numlist[i])
#     sum_ny_liste = np.sum(ny_liste)
#     return sum_ny_liste
#
# Incorrect usage of parentheses:
# The code uses parentheses after numlist in the loop, as if trying to call it as a function. However, numlist is a list, not a function, so using parentheses in this context is incorrect.
#
# UnboundLocalError("local variable 'zum' referenced before assignment")
#
# def sum_larger(numlist,n):
#     for i in numlist:
#         if i > n:
#             zum += i
#     return zum
#
# Incorrect variable name:
# The code uses the variable name 'zum', but it appears that you intended to use the name 'sum' to store the sum of elements greater than 'n'. However, 'sum' is a built-in function in Python, so using it as a variable name can lead to unexpected behavior and errors. It's recommended to use a different variable name to avoid conflicts.
#
# AssertionError('8 != 15')
#
# def sum_larger(numlist, n):
#
#     for i in range(len(numlist)):
#         sum = 0
#         if numlist[i] > n:
#             sum += numlist[i]
#     return sum
#
# Incorrect placement of the sum variable:
# The code initializes the sum variable inside the loop. As a result, the variable is reset to 0 for each iteration, and only the last element greater than n contributes to the sum. The final result returned by the function is the value of sum from the last iteration.
#
# Oppgave 2
#
# TypeError("'function' object is not iterable")
# def car_type(n_pass,wt,person):
#     totalvekt = wt
#     sitteplasser = n_pass
#     persontransport = True
#     for car in car_type:
#         for sitteplasser in car_type:
#             return True
#             if sitteplasser <= 8:
#                 return  "M1"
#             if sitteplasser > 8 and totalvekt < 5000:
#                 return "M2"
#             if sitteplasser > 8 and totalvekt > 5000:
#                 return "M3"
#         else:
#             return False
#             if totalvekt >= 3500:
#                 return "N1"
#             if totalvekt > 3500 <= 12000:
#                 return "N2"
#             if totalvekt > 12000:
#                 return "N3"
#
# Incorrect iteration over the function:
# The code attempts to iterate over the function itself with the statement for car in car_type:. However, you should be iterating over a collection or iterable object, not the function itself. This leads to the TypeError since the function object is not iterable.
#
# NameError("name 'true' is not defined")
#
# def car_type(n_pass, wt, person):
#
#     if person == true: #persontransport vil g√• inn her
#         if n_pass <= 7:
#             return "M1"
#         elif n_pass ==8 and wt <= 5000:
#             return "M2"
#         else:
#             return "M3"
#
#     # skjekker n√• varetransport
#
#     if totalvekt <= 3500:
#         return "N1"
#     elif totalvekt <= 12000:
#         return "N2"
#     else:
#         return "N3"
#
# Incorrect usage of 'true':
# The code uses 'true' instead of 'True'. In Python, boolean literals are represented as 'True' (with a capital 'T') and 'False' (with a capital 'F'). Using 'true' instead of 'True' results in a NameError since 'true' is not a defined name in Python.
#
# UnboundLocalError("local variable 'kategori' referenced before assignment")
#
# def car_type(n_pass, wt, person):
#     katergori=""
#     if person==False and wt<3500:
#         kategori+="N1"
#     elif person==False and 3500<wt<12000:
#         kategori+="N2"
#     elif person==False and wt>12000:
#         kategori+="N3"
#     elif person==True and n_pass<=8:
#         kategori+="M1"
#     elif person==True and n_pass>8 and wt<=5000:
#         kategori+="M2"
#     else:
#         kategori+="M3"
#     return kategori
#
# Incorrect variable assignment:
# The code attempts to concatenate a string value to the variable 'kategori', but 'kategori' is not properly initialized before concatenation. This leads to the UnboundLocalError since 'kategori' is referenced before it is assigned a value.
#
# Oppgave 3
#
# NameError("name 'integer' is not defined")
#
# def sum_larger(numlist,n):
#     sum = 0
#     for i in numlist:
#         if i>n:
#             sum += i
#     return sum
#
# Incorrect variable name:
# The code uses the variable name 'sum', which is the name of a built-in function in Python. Using the same name as a built-in function can lead to unexpected behavior and errors. It's recommended to use a different variable name to avoid conflicts.
#
# TypeError('only integer scalar arrays can be converted to a scalar index')
#
# def sum_larger(numlist,n):
#     sum = 0
#     for tall in numlist:
#         if tall>n:
#             sum+=tall
#     return sum
#
# Incorrect variable name:
# The code uses the variable name sum, which is the name of a built-in function in Python. This causes a logical error and can lead to unexpected behavior. It's recommended to use a different variable name to avoid conflicts.
#
# IndexError('only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices')
#
# def sum_larger(lst,n):
#
#     tallene = []
#
#     for i in lst:
#         if i>n:
#             tallene.append(i)
#     return sum(tallene)
#
# sum_larger([2,5,4,7,3,8],5)
#
# Incorrect usage of indexing:
# The code tries to access elements of the list tallene using an invalid index. It attempts to use i as an index, but i is a value from the original list lst, not an index.

# %% [markdown]
# Oppgave 1
#
# Incorrect usage of parentheses:
# The code uses parentheses after numlist in the loop, as if trying to call it as a function. However, numlist is a list, not a function, so using parentheses in this context is incorrect.
#
# Incorrect variable name:
# The code uses the variable name 'zum', but it appears that you intended to use the name 'sum' to store the sum of elements greater than 'n'. However, 'sum' is a built-in function in Python, so using it as a variable name can lead to unexpected behavior and errors. It's recommended to use a different variable name to avoid conflicts.
#
# Incorrect placement of the sum variable:
# The code initializes the sum variable inside the loop. As a result, the variable is reset to 0 for each iteration, and only the last element greater than n contributes to the sum. The final result returned by the function is the value of sum from the last iteration.
#
# Oppgave 2
#
# Incorrect iteration over the function:
# The code attempts to iterate over the function itself with the statement for car in car_type:. However, you should be iterating over a collection or iterable object, not the function itself. This leads to the TypeError since the function object is not iterable.
#
# Incorrect usage of 'true':
# The code uses 'true' instead of 'True'. In Python, boolean literals are represented as 'True' (with a capital 'T') and 'False' (with a capital 'F'). Using 'true' instead of 'True' results in a NameError since 'true' is not a defined name in Python.
#
# Incorrect variable assignment:
# The code attempts to concatenate a string value to the variable 'kategori', but 'kategori' is not properly initialized before concatenation. This leads to the UnboundLocalError since 'kategori' is referenced before it is assigned a value.
#
# Oppgave 3
#
# Incorrect variable name:
# The code uses the variable name 'sum', which is the name of a built-in function in Python. Using the same name as a built-in function can lead to unexpected behavior and errors. It's recommended to use a different variable name to avoid conflicts.
#
# Incorrect variable name:
# The code uses the variable name sum, which is the name of a built-in function in Python. This causes a logical error and can lead to unexpected behavior. It's recommended to use a different variable name to avoid conflicts.
#
# Incorrect usage of indexing:
# The code tries to access elements of the list tallene using an invalid index. It attempts to use i as an index, but i is a value from the original list lst, not an index.
